# %% [markdown]
# # Python for Data Science Project: Predicting bike counts in Paris

# %% [markdown]
# ## Introduction

# %% [markdown]
# Authors: Alexander Bohane - Nacer Hadni
#
# The motivation behind this project is to predict the number of bikes passing by 'bike counters' in Paris for a given hour. These bike counters are spread over Paris and data is provided to us every hour or so over a specific time period. We will make use of this given dataset and utilise external data sources such as weather data in Paris for the required time period. Using this data we hope to accurately predict the logarithm of the bike count and will be assessed using an unseen dataset of features. The evaluation metric will be the RMSE (Root Mean Square Error)

# %% [markdown]
# ## Data Loading and Initial Exploration

# %% [markdown]
# The data is presented in a .parquet format. We have access to a train and test set which we will load.
#
# NOTE: the test and train is initially split for convenience and the combination of both is equal to the train set in the kaggle challenge. We will be assessed on `final_test.parquet`
#
# We will thus merge `train.parquet` and `test.parquet` as one train set in our modelling and perform cross validation on the entirety of this dataset `df_all`. First let's import some preliminary packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# Now we will fetch the data and merge

# %%
df_train = pd.read_parquet("data/train.parquet")
df_test = pd.read_parquet("data/test.parquet")

# Merge both datasets in order
df_all = pd.concat([df_train, df_test])

# %% [markdown]
# Let's explore the initial dataset and see what columns we are dealing with and see how many observations we have.
# First, we should check for missing values

# %%
df_all.isna().sum()
# Out:
# counter_id                   0
# counter_name                 0
# site_id                      0
# site_name                    0
# bike_count                   0
# date                         0
# counter_installation_date    0
# counter_technical_id         0
# latitude                     0
# longitude                    0
# log_bike_count               0
# dtype: int64

# %% [markdown]
# Luckily, there are no missing values in the dataset!

# %%
df_all.head(2)
# Out:
#                 counter_id              counter_name    site_id  \
# 48321  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48324  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#                   site_name  bike_count                date  \
# 48321  28 boulevard Diderot         0.0 2020-09-01 02:00:00
# 48324  28 boulevard Diderot         1.0 2020-09-01 03:00:00
#
#       counter_installation_date counter_technical_id   latitude  longitude  \
# 48321                2013-01-18          Y2H15027244  48.846028   2.375429
# 48324                2013-01-18          Y2H15027244  48.846028   2.375429
#
#        log_bike_count
# 48321        0.000000
# 48324        0.693147

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 496771 entries, 48321 to 929187
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   counter_id                 496771 non-null  category
#  1   counter_name               496771 non-null  category
#  2   site_id                    496771 non-null  int64
#  3   site_name                  496771 non-null  category
#  4   bike_count                 496771 non-null  float64
#  5   date                       496771 non-null  datetime64[ns]
#  6   counter_installation_date  496771 non-null  datetime64[ns]
#  7   counter_technical_id       496771 non-null  category
#  8   latitude                   496771 non-null  float64
#  9   longitude                  496771 non-null  float64
#  10  log_bike_count             496771 non-null  float64
# dtypes: category(4), datetime64[ns](2), float64(4), int64(1)
# memory usage: 32.2 MB

# %% [markdown]
# In total we have 496771 observations and 11 columns including our target variable: `log_bike_count`.
# We have several numerical features that are floats and one that is in integer format:
#  - bike_count
#  - latitude
#  - longitude
#  - log_bike_count
#  - site_id (int64)
#
#  We also have two features that are given in datetime:
#  - date
#  - counter_installation_date
#
#  And finally three categorical variables:
#  - counter_id
#  - counter_name
#  - counter_technical_id
#
# Let's now look at how the data is structured:

# %%
df_all.nunique()
# Out:
# counter_id                     56
# counter_name                   56
# site_id                        30
# site_name                      30
# bike_count                    998
# date                         8973
# counter_installation_date      22
# counter_technical_id           30
# latitude                       30
# longitude                      30
# log_bike_count                998
# dtype: int64

# %% [markdown]
# ### Sites and Counters

# %%
df_all_site_names_sorted = df_all.groupby('site_name')['counter_name'].nunique()
print(df_all_site_names_sorted.to_frame())
print(f"Total unique counter names: {df_all_site_names_sorted.sum()}")

# sort values 2-> 1
# Out:
#                                            counter_name
# site_name
# 152 boulevard du Montparnasse                         2
# 18 quai de l'Hôtel de Ville                           2
# 20 Avenue de Clichy                                   2
# 254 rue de Vaugirard                                  2
# 27 quai de la Tournelle                               2
# 28 boulevard Diderot                                  2
# 36 quai de Grenelle                                   2
# 38 rue Turbigo                                        2
# 39 quai François Mauriac                              2
# 6 rue Julia Bartet                                    2
# 67 boulevard Voltaire SE-NO                           1
# 90 Rue De Sèvres                                      2
# Face 104 rue d'Aubervilliers                          2
# Face au 25 quai de l'Oise                             2
# Face au 4 avenue de la porte de Bagnolet              2
# Face au 40 quai D'Issy                                2
# Face au 48 quai de la marne                           2
# Face au 70 quai de Bercy                              2
# Face au 8 avenue de la porte de Charenton             2
# Pont Charles De Gaulle                                2
# Pont de Bercy                                         2
# Pont de la Concorde S-N                               1
# Pont des Invalides N-S                                1
# Pont des Invalides S-N                                1
# Quai d'Orsay                                          2
# Totem 64 Rue de Rivoli                                2
# Totem 73 boulevard de Sébastopol                      2
# Totem 85 quai d'Austerlitz                            2
# Totem Cours la Reine                                  2
# Voie Georges Pompidou                                 2
# Total unique counter names: 56

# %% [markdown]
# It looks like we have a total of 30 sites in Paris, identified by `site_name`, `counter_technical_id` and `site_id` and their respective `longitude` and `latitude`.
#
# By exploring further, we can see that each site is subdivided into either 1 or 2 counters identified by `counter_id` and `counter_name`. All but four sites have 2 counters they are:
#
# - 67 boulevard Voltaire SE-NO
# - Pont de la Concorde S-N
# - Pont des Invalides N-S
# - Pont des Invalides S-N
#
# We can infer from the data format that every site with 2 counters contains two directions, likely because it is a two-way street: ie. a counter for one cardinal direction (example North) and a counter for the opposite cardinal direction (example south).
#
# For the sites with only one counter it is possible that they are simply one way streets. For 'Pont des Invalides N-S and S-N' there are two separate sites despite the same name. Perhaps this is an error and they have not been grouped together into one site, or they are two seperate one way streets but in very close proximity to each other.

# %% [markdown]
# ### Dates and bike counts

# %% [markdown]
# The date appears to be structured and given by hour. Let's check the range of the data

# %%
print(df_all['date'].min())
print(df_all['date'].max())
# Out:
# 2020-09-01 01:00:00
# 2021-09-09 23:00:00

# %% [markdown]
# We can see our data runs from 01/09/2020 to 09/09/2021 (European date time) which is just over a year. Next let's  check if there might be gaps in the time data

# %%
df_all_counter_dates = df_all.groupby('counter_name')['date'].nunique()
print((df_all_counter_dates - 8973).sort_values(ascending=True).head(10))
# Out:
# counter_name
# 254 rue de Vaugirard SO-NE          -2397
# 254 rue de Vaugirard NE-SO          -2397
# Voie Georges Pompidou SO-NE          -455
# Voie Georges Pompidou NE-SO          -455
# 152 boulevard du Montparnasse E-O      -6
# 152 boulevard du Montparnasse O-E      -6
# Totem Cours la Reine E-O               -1
# 20 Avenue de Clichy SE-NO               0
# Face au 70 quai de Bercy N-S            0
# Face au 70 quai de Bercy S-N            0
# Name: date, dtype: int64

# %% [markdown]
# There are 8973 unique datetimes over our time period corresponding to every hour between our start time and end time which is about 373 days.
#
#  - Voie Georges Pompidou NE-SO and SO-NE have 455 in time data.
#  - 254 rue de Vaugirard NE-SO and SO-NE have 2397 gaps in time date
#  - 152 boulevard du Montparnasse E-O and O-E have 6 gaps in the data
#  - Totem Cours la Reine E-O has 1 gap in the time data.
#
#
# There are two possible explanations for less time data: either the counter was installed after the start time of our data (after 1st September 2020) or the counter stopped working for some amount of time.

# %%
specific_counter_data_1 = df_all[df_all['counter_name'] == 'Voie Georges Pompidou SO-NE']
specific_counter_data_2 = df_all[df_all['counter_name'] == '254 rue de Vaugirard NE-SO']

# Voie Georges Pompidou installation date
print(specific_counter_data_1['counter_installation_date'].unique())

# 254 rue de Vaugirard installation date
print(specific_counter_data_2['counter_installation_date'].unique())
# Out:
# <DatetimeArray>
# ['2017-12-15 00:00:00']
# Length: 1, dtype: datetime64[ns]
# <DatetimeArray>
# ['2020-11-29 00:00:00']
# Length: 1, dtype: datetime64[ns]

# %%
df_all.head()
# Out:
#                 counter_id              counter_name    site_id  \
# 48321  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48324  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48327  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48330  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48333  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#                   site_name  bike_count                date  \
# 48321  28 boulevard Diderot         0.0 2020-09-01 02:00:00
# 48324  28 boulevard Diderot         1.0 2020-09-01 03:00:00
# 48327  28 boulevard Diderot         0.0 2020-09-01 04:00:00
# 48330  28 boulevard Diderot         4.0 2020-09-01 15:00:00
# 48333  28 boulevard Diderot         9.0 2020-09-01 18:00:00
#
#       counter_installation_date counter_technical_id   latitude  longitude  \
# 48321                2013-01-18          Y2H15027244  48.846028   2.375429
# 48324                2013-01-18          Y2H15027244  48.846028   2.375429
# 48327                2013-01-18          Y2H15027244  48.846028   2.375429
# 48330                2013-01-18          Y2H15027244  48.846028   2.375429
# 48333                2013-01-18          Y2H15027244  48.846028   2.375429
#
#        log_bike_count
# 48321        0.000000
# 48324        0.693147
# 48327        0.000000
# 48330        1.609438
# 48333        2.302585

# %% [markdown]
# 254 rue de Vaugirard counters were installed in the end of november 2020, which is 3 months after the start time of our data which explains the 2397 missing hours.

# %% [markdown]
# ### Bike counts

# %% [markdown]
# Here we show the total bike count per counter for all sites over the whole time period to see which counter is the most frequented

# %%
df_count_over_all_sites = df_all.groupby(['counter_name'])['log_bike_count'].sum().sort_values(
    ascending=False)
df_count_over_all_sites
# Out:
# counter_name
# Totem 73 boulevard de Sébastopol S-N               41419.409286
# Totem 73 boulevard de Sébastopol N-S               39506.363892
# Totem 64 Rue de Rivoli O-E                         38265.490779
# 67 boulevard Voltaire SE-NO                        36534.392600
# 27 quai de la Tournelle SE-NO                      35129.735285
# Totem 64 Rue de Rivoli E-O                         34963.278228
# Face au 48 quai de la marne SO-NE                  33877.922775
# Totem Cours la Reine O-E                           33367.721185
# Quai d'Orsay E-O                                   33218.873448
# Face au 48 quai de la marne NE-SO                  32961.359877
# Totem 85 quai d'Austerlitz SE-NO                   32891.675136
# 38 rue Turbigo NE-SO                               32274.777744
# 38 rue Turbigo SO-NE                               31982.553020
# 36 quai de Grenelle NE-SO                          31830.790114
# 27 quai de la Tournelle NO-SE                      31251.531872
# Pont de la Concorde S-N                            30559.370891
# 90 Rue De Sèvres NE-SO                             30245.504909
# Totem 85 quai d'Austerlitz NO-SE                   30217.947317
# Face au 25 quai de l'Oise SO-NE                    30014.026276
# Quai d'Orsay O-E                                   29786.710768
# 39 quai François Mauriac NO-SE                     28980.172040
# 39 quai François Mauriac SE-NO                     28717.685539
# 6 rue Julia Bartet NE-SO                           28582.481037
# Face au 25 quai de l'Oise NE-SO                    28576.907448
# 28 boulevard Diderot O-E                           27786.250845
# Voie Georges Pompidou SO-NE                        27482.034938
# 36 quai de Grenelle SO-NE                          27338.126063
# Totem Cours la Reine E-O                           27057.443075
# Pont de Bercy NE-SO                                25990.752957
# Face au 70 quai de Bercy N-S                       25933.357117
# Face au 4 avenue de la porte de Bagnolet E-O       25836.342318
# 18 quai de l'Hôtel de Ville SE-NO                  25772.227401
# 6 rue Julia Bartet SO-NE                           25771.961693
# 152 boulevard du Montparnasse E-O                  25688.064428
# Face 104 rue d'Aubervilliers N-S                   25582.116866
# Pont Charles De Gaulle NE-SO                       25477.803054
# 20 Avenue de Clichy NO-SE                          24816.181261
# Pont de Bercy SO-NE                                24735.787711
# 152 boulevard du Montparnasse O-E                  24692.989269
# 20 Avenue de Clichy SE-NO                          24675.903208
# Pont Charles De Gaulle SO-NE                       24302.842145
# 90 Rue De Sèvres SO-NE                             24263.329032
# Face au 8 avenue de la porte de Charenton SE-NO    24216.564777
# Face 104 rue d'Aubervilliers S-N                   24112.153423
# Face au 70 quai de Bercy S-N                       24068.992865
# 18 quai de l'Hôtel de Ville NO-SE                  23187.270305
# Voie Georges Pompidou NE-SO                        22993.378353
# Pont des Invalides N-S                             22903.214898
# 254 rue de Vaugirard SO-NE                         22774.185028
# Face au 4 avenue de la porte de Bagnolet O-E       21267.969355
# Pont des Invalides S-N                             20964.887166
# Face au 8 avenue de la porte de Charenton NO-SE    20726.285272
# 254 rue de Vaugirard NE-SO                         20511.379469
# Face au 40 quai D'Issy NE-SO                       13950.532407
# Face au 40 quai D'Issy SO-NE                       12297.869363
# 28 boulevard Diderot E-O                            7776.110383
# Name: log_bike_count, dtype: float64

# %%
# Group by 'site_name' and sum 'log_bike_count'
grouped_counts = df_all.groupby(['site_name'])['log_bike_count'].sum().reset_index()

# Merge the summed counts back into the original DataFrame
df_all = df_all.merge(grouped_counts, on='site_name', suffixes=('', '_sum_total'))


#gets rid of index

# %%
import matplotlib.colors as mcolors
from folium.plugins import FloatImage


min_count = df_all['log_bike_count_sum_total'].min()
max_count = df_all['log_bike_count_sum_total'].max()
norm = mcolors.Normalize(vmin=min_count, vmax=max_count, clip=True)

# Create a colormap
mapper = plt.cm.ScalarMappable(norm=norm, cmap=plt.cm.gnuplot)

# Create the map
m = folium.Map(location=df_all[["latitude", "longitude"]].mean(axis=0), zoom_start=13)

# Loop to create markers with color based on 'log_bike_count_sum'
for _, row in (
    df_all[["site_name", "latitude", "longitude", "log_bike_count_sum_total"]]
    .drop_duplicates("site_name")
    .iterrows()
):
    color = mcolors.to_hex(mapper.to_rgba(row['log_bike_count_sum_total']))
    folium.CircleMarker(
        location=row[["latitude", "longitude"]].values.tolist(), 
        popup=row["site_name"],
        radius=10,
        color=color,
        fill=True,
        fill_color=color
    ).add_to(m)

fig, ax = plt.subplots(figsize=(6, 1))
fig.subplots_adjust(bottom=0.5)

# Create a colormap
cmap = plt.cm.gnuplot
norm = mcolors.Normalize(vmin=min_count, vmax=max_count)

# Create a colorbar in the figure
cb = fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap), cax=ax, orientation='horizontal')
cb.set_label('Log Bike Count')


# Add the colorbar image to the map
FloatImage(cb, bottom=0, left=110).add_to(m)


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e0201956bfcec80e738e5e400d78f76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_33b87141a3b6fbb771d5c37a6e4e67ed {
#                         position: absolute;
#                         bottom: 0%;
#                         left: 110%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e0201956bfcec80e738e5e400d78f76&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_33b87141a3b6fbb771d5c37a6e4e67ed&quot; alt=&quot;float_image&quot;
#                  src=&quot;&lt;matplotlib.colorbar.Colorbar object at 0x132ea6b90&gt;&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e0201956bfcec80e738e5e400d78f76 = L.map(
#                 &quot;map_1e0201956bfcec80e738e5e400d78f76&quot;,
#                 {
#                     center: [48.85434349826781, 2.3454792069967856],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46871312a306e2513a5354fba785d661 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_46871312a306e2513a5354fba785d661.addTo(map_1e0201956bfcec80e738e5e400d78f76);
#
#             var circle_marker_e245897f8a9e43aea584fb37f995afbe = L.circleMarker(
#                 [48.846028, 2.375429],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7e04ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7e04ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e0201956bfcec80e738e5e400d78f76);
#
#
#         var popup_d04c5aded6c5e30cfee166f4881747bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d840da7a5fc7e7b5f147fe18ba6a310 = $(`&lt;div id=&quot;html_9d840da7a5fc7e7b5f147fe18ba6a310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28 boulevard Diderot&lt;/div&gt;`)[0];
#                 popup_d04c5aded6c5e30cfee166f4881747bd.setContent(html_9d840da7a5fc7e7b5f147fe18ba6a310);
#
#
#
#         circle_marker_e245897f8a9e43aea584fb37f995afbe.bindPopup(popup_d04c5aded6c5e30cfee166f4881747bd)
#         ;
#
#
#
#
#             var circle_marker_d03e0d9ba99425babc4d43e4fe7c0167 = L.circleMarker(
#                 [48.83436, 2.377],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c73a00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c73a00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e0201956bfcec80e738e5e400d78f76);
#
#
#         var popup_77b354182b18bd15b19ef7611f594fc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a949fc1ec909e3d09b9b71fe4676d31 = $(`&lt;div id=&quot;html_7a949fc1ec909e3d09b9b71fe4676d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;39 quai François Mauriac&lt;/div&gt;`)[0];
#                 popup_77b354182b18bd15b19ef7611f594fc5.setContent(html_7a949fc1ec909e3d09b9b71fe4676d31);
#
#
#
#         circle_marker_d03e0d9ba99425babc4d43e4fe7c0167.bindPopup(popup_77b354182b18bd15b19ef7611f594fc5)
#         ;
#
#
#
#
#             var circle_marker_751dbddbc1141ab64fbd60e3dfc75888 = L.circleMarker(
#                 [48.85372, 2.35702],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ae1a35&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ae1a35&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e0201956bfcec80e738e5e400d78f76);
#
#
#         var popup_80d5d0aa189bb535d4aa90b38bcdb2ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0b14beb66060e9fe89aeca93fcfce61 = $(`&lt;div

# %% [markdown]
# We can see that the most frequented bike counters are typically clustered in the centre of paris, and as we move further away towards the outskirts of Paris, the bike count is slightly lower. There are two outliers on the lower end of the spectrum:
#
# - Pont des Invalides N-S
# - Pont des Invalides S-N
#
# As we saw before, these two sites appear to be for the same location, we should probably group these together in our feature engineering into one site.

# %% [markdown]
# Let's get a better idea of how the bike count varies with time. We can compute the average bike count for all counters at each time step and plot over a specific time period

# %%
fig, ax = plt.subplots(figsize=(14, 4))

# Define the time frame
start_date = pd.to_datetime("2020/09/09")
end_date = pd.to_datetime("2020/09/10")

# Mask for the most frequent counter
mask_most_freq = (
    (df_all["counter_name"] == "Totem 73 boulevard de Sébastopol S-N")
    & (df_all["date"] >= start_date)
    & (df_all["date"] < end_date)
)



# Apply the same date filter to the entire dataset for calculating the average
mask_timeframe = (df_all["date"] >= start_date) & (df_all["date"] < end_date)
average_counts = df_all[mask_timeframe].groupby('date')['bike_count'].mean()


# Plotting the data for the most frequent counter
df_all[mask_most_freq].plot(x="date", y="bike_count", ax=ax, label='Most Frequent Counter')
# Plotting the average bike_count
average_counts.plot(ax=ax, label='Average Bike Count', color='red')

# Adding legend and labels
ax.legend()
ax.grid()
ax.set_xlabel('Date')
ax.set_ylabel('Bike Count')
ax.set_title('Bike Count Over Time for Two Weeks')

plt.show()

# %% [markdown]
# There seems to be a clear cyclical daily trend for our bike count data. Above we can see that there are generally two peaks during the day, one in the morning around 7/8 AM and one other larger peak around 4/5 PM. This is logical as it indicates people commuting to and from work.

# %%
# Calculate average_counts
average_counts = df_all.groupby('date')['bike_count'].mean()

# Masks for the specific counters
mask_missing = df_all["counter_name"] == "254 rue de Vaugirard NE-SO"
mask_missing_two = df_all["counter_name"] == "Voie Georges Pompidou SO-NE"

# Create subplots - 2 rows, 1 column
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8))  # Adjust the figure size as needed

# First graph - Average and Missing Vals Counter
average_counts.plot(ax=ax1, label='Average Bike Count')
df_all[mask_missing].plot(x="date", y="bike_count", ax=ax1, label='Bike Counter 254 rue de Vaugirard ')
ax1.legend()
ax1.set_xlabel('Date')
ax1.set_ylabel('Bike Count')
ax1.set_title('Bike Count Over Time for Counter 1')

# Second graph - Average and Missing Vals Counter Two
average_counts.plot(ax=ax2, label='Average Bike Count')
df_all[mask_missing_two].plot(x="date", y="bike_count", ax=ax2, label='Bike Counter Voie Georges Pompidou', alpha=0.5)

ax2.legend()
ax2.set_xlabel('Date')
ax2.set_ylabel('Bike Count')
ax2.set_title('Bike Count Over Time for Counter 2')

plt.tight_layout()  # Adjusts the plots to fit into the figure area.
plt.show()

# %%
# Ensure 'date' is the index for df_all
df_date_time = df_all.copy()
df_date_time['date'] = pd.to_datetime(df_all['date'])
df_date_time.set_index('date', inplace=True)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Calculate average log counts
average_log_counts = df_date_time.groupby('date')['log_bike_count'].mean()

# You need to determine the appropriate period
# For daily data with weekly seasonality, it would be 7
# For daily data with annual seasonality, it might be 365 (or 366 for leap years), and so on
# by day 
#168
#720
#8760

period = 168
# Example: weekly seasonality in daily data

# Decompose the 'average_log_counts' time series
decomposition = seasonal_decompose(average_log_counts, model='additive', period=period)

# Extract the components
trend = decomposition.trend


plt.figure(figsize=(12, 6))
decomposition.trend.plot()

# Specify the dates of events
couvre_feu_dates = ['2020-10-15','2020-10-29','2020-12-16', '2021-4-3', '2021-5-4', '2021-6-20']
confinement_dates = ['2020-10-30', '2020-12-15', '2021-4-4', '2021-5-3']

# Shade regions for couvre feu dates
for i in range(0, len(couvre_feu_dates), 2):
    start_date = pd.to_datetime(couvre_feu_dates[i])
    end_date = pd.to_datetime(couvre_feu_dates[i + 1]) if i + 1 < len(couvre_feu_dates) else None
    plt.axvspan(start_date, end_date, color='red', alpha=0.3, label='Couvre Feu' if i == 0 else "")

# Shade regions for confinement dates
for i in range(0, len(confinement_dates), 2):
    start_date = pd.to_datetime(confinement_dates[i])
    end_date = pd.to_datetime(confinement_dates[i + 1]) if i + 1 < len(confinement_dates) else None
    plt.axvspan(start_date, end_date, color='black', alpha=0.3, label='Confinement' if i == 0 else "")

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Average Log Count')
plt.title('Trend with Event Date Regions Marked')

# Add the legend
plt.legend()

plt.show()

# %% [markdown]
# This graph shows the trend on a **daily** cyclical basis with shaded regions highlighted showing lockdowns and curfews in paris. There is clearly a trend in which less people cycled during the lockdowns and mandatory curfews. We can also see a massive dip in December which is probably due to Christmas day (and days around Christmas).

# %% [markdown]
# ## FEATURE ENGINEERING IDEAS

# %% [markdown]
# - Merge Pont des Invalides N-S and S-N into one site
# - Split into cardinal directions for each counter
# - Split into grid showing cardinal LOCATION of each counter N, N-E, E, S-E, S, S-W, W, N-W
# - Or distance measure using longitude and latitude from centre of paris so we can delete latitude and longitude in the actual model
# - Add is holiday, is weekend, is weekday
# - Seasonality
# - Distance to every other counter (30 columns)

# %% [markdown]
# We want to create a feature that combines latitude and longitude to find the distance of each counter to the centre of paris. We can do this by finding the coordinates of the centre of Paris. We will choose 'La Place Dauphine' which is located right in the centre of Paris on l'Ile de la Cité. The coordinates are:
#
# 48.8565° N, 2.3426° E
#
# We can use the euclidean distance for each counter to compute distance from centre:
#
# $\sqrt{(LATITUDE-48.8565)^2 + (LONGITUDE-2.3426)^2}$

# %% [markdown]
# MORE IDEAS
#
# - Add correction factor for COVID
# - Use FFT and DFT for
# - Meteo
# - Population

# %%
def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, "year"] = X["date"].dt.year
    X.loc[:, "month"] = X["date"].dt.month
    X.loc[:, "day"] = X["date"].dt.day
    X.loc[:, "weekday"] = X["date"].dt.weekday
    X.loc[:, "hour"] = X["date"].dt.hour

    # Finally we can drop the original columns from the dataframe
    return X

# %%
def _distance_from_paris_centre(X):
    X = X.copy()  # modify a copy of X
    X.loc[:, 'distance_paris_centre'] = np.sqrt((X['latitude']-48.8565)**2 + (X['longitude']-2.3426)**2)
    
    return X.drop(columns=['latitude','longitude'])

# %%
from workalendar.europe import France  

def is_holiday_and_weekend(X):
    X = X.copy()
    # Initialize the France calendar from the workalendar library
    cal = France()

    # Convert 'year', 'month', 'day' to a datetime object
    X['date'] = pd.to_datetime(X[['year', 'month', 'day']])

    # Add a column for public holidays
    X['is_public_holiday'] = X['date'].apply(lambda x: cal.is_holiday(x)).astype(int)

    # Add a column for weekends
    # 5 and 6 represent Saturday and Sunday in 'weekday' column
    X['is_weekend'] = X['weekday'].apply(lambda x: x in [5, 6]).astype(int)

    return X  # Optionally dropping individual date columns

# %%
def add_covid_restriction_column(X):
    X = X.copy()
    X['date'] = pd.to_datetime(X[['year', 'month', 'day']])

    # Initialize the column with 'No Restriction' (0)
    X['covid_restriction'] = 0

    # Couvre feu (Curfew) dates
    couvre_feu_dates = [('2020-12-16', '2021-4-3'), 
                        ('2021-5-4', '2021-6-20')]

    # Confinement (Lockdown) dates
    confinement_dates = [('2020-10-30', '2020-12-15'), 
                         ('2021-4-4', '2021-5-3')]

    # Apply 'Curfew' (1) and 'Lockdown' (2) based on dates
    for start_date, end_date in couvre_feu_dates:
        X.loc[X['date'].between(pd.Timestamp(start_date), pd.Timestamp(end_date)), 'covid_restriction'] = 1

    for start_date, end_date in confinement_dates:
        X.loc[X['date'].between(pd.Timestamp(start_date), pd.Timestamp(end_date)), 'covid_restriction'] = 2

    return X

# %%
df_fe = _encode_dates(df_all)
df_fe = is_holiday_and_weekend(df_fe) 

df_fe = add_covid_restriction_column(df_fe)

df_fe = _distance_from_paris_centre(df_fe)

# %%
# Calculate the mean bike count for each day of the week
average_weekly_counts = df_fe.groupby('weekday')['bike_count'].mean()

# Mapping weekday numbers to names for clarity in the plot
weekday_names = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
average_weekly_counts.index = average_weekly_counts.index.map(weekday_names)

# Plotting
plt.figure(figsize=(8, 6))
average_weekly_counts.plot(kind='bar', color='skyblue')

plt.title('Average Bike Count for Each Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Bike Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# There seems to be less people riding bikes on weekends versus weekdays, indicating that most people may be riding bikes to commute to and from work rather than for leisure.

# %%
# Create a 'year-month' column for chronological sorting
df_fe['year_month'] = pd.to_datetime(df_fe['year'].astype(str) + '-' + df_fe['month'].astype(str))

# Calculate the mean bike count for each 'year-month'
average_monthly_counts = df_fe.groupby('year_month')['bike_count'].mean()

# Plotting
plt.figure(figsize=(10, 6))
average_monthly_counts.plot(kind='bar', color='skyblue')
plt.title('Average Bike Count for Each Month Over Time')
plt.xlabel('Month')
plt.ylabel('Average Bike Count')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# This graph clearly shows dips in bike counts in the winter period, but also in August. This is likely because people go on holiday in August and in the holidays. The other dips could be attributed to COVID related factors but this is hard to assess as we only have data for a COVID year (and not a regular non-COVID year)

# %%
df_fe = df_fe.drop(['year_month'], axis=1)

# %%
df_fe.head()
# Out:
#             counter_id              counter_name    site_id  \
# 0  100007049-102007049  28 boulevard Diderot E-O  100007049
# 1  100007049-102007049  28 boulevard Diderot E-O  100007049
# 2  100007049-102007049  28 boulevard Diderot E-O  100007049
# 3  100007049-102007049  28 boulevard Diderot E-O  100007049
# 4  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#               site_name  bike_count       date counter_installation_date  \
# 0  28 boulevard Diderot         0.0 2020-09-01                2013-01-18
# 1  28 boulevard Diderot         1.0 2020-09-01                2013-01-18
# 2  28 boulevard Diderot         0.0 2020-09-01                2013-01-18
# 3  28 boulevard Diderot         4.0 2020-09-01                2013-01-18
# 4  28 boulevard Diderot         9.0 2020-09-01                2013-01-18
#
#   counter_technical_id  log_bike_count  log_bike_count_sum_total  year  month  \
# 0          Y2H15027244        0.000000              35562.361228  2020      9
# 1          Y2H15027244        0.693147              35562.361228  2020      9
# 2          Y2H15027244        0.000000              35562.361228  2020      9
# 3          Y2H15027244        1.609438              35562.361228  2020      9
# 4          Y2H15027244        2.302585              35562.361228  2020      9
#
#    day  weekday  hour  is_public_holiday  is_weekend  covid_restriction  \
# 0    1        1     2                  0           0                  0
# 1    1        1     3                  0           0                  0
# 2    1        1     4                  0           0                  0
# 3    1        1    15                  0           0                  0
# 4    1        1    18                  0           0                  0
#
#    distance_paris_centre
# 0               0.034459
# 1               0.034459
# 2               0.034459
# 3               0.034459
# 4               0.034459

# %% [markdown]
# # FE

# %% [markdown]
# # Modelling

# %%
from datetime import datetime
def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, "year"] = X["date"].dt.year
    X.loc[:, "month"] = X["date"].dt.month
    X.loc[:, "day"] = X["date"].dt.day
    X.loc[:, "weekday"] = X["date"].dt.weekday
    X.loc[:, "hour"] = X["date"].dt.hour

    # Finally we can drop the original columns from the dataframe
    return X


conf = [(datetime(2020, 3, 17), datetime(2020, 5, 10)), (datetime(2020, 10, 30), datetime(2020, 11, 27)), (datetime(2021, 4, 3), datetime(2021, 5, 2))]
conf_a = [(datetime(2020, 5, 11), datetime(2020, 6, 1)), (datetime(2020, 11, 28), datetime(2020, 12, 15))]
c_v = [(datetime(2020, 12, 16), datetime(2021, 4, 2)), (datetime(2021, 5, 3), datetime(2021, 6, 20))]

def is_in_range(date):
    for start, end in conf:
        if start <= date <= end:
            return 3
    for start, end in conf_a:
        if start <= date <= end:
            return 2
    for start, end in c_v:
        if start <= date <= end:
            return 1
    if date == datetime(2020, 12, 25):
        return 0
    return 0

def apply_confinement_status(X):
    X = X.copy()  # To avoid modifying the original DataFrame
    X['Confinement'] = X['date'].apply(is_in_range)
    return X

from datetime import datetime

def covid_scaled_count(X):
    X = X.copy()
    # Define the COVID period
    covid_start = datetime(2020, 10, 15)
    covid_end = datetime(2021, 6, 20)
    covid_impact_factor = 1.21

    # Create a boolean mask for the COVID period
    covid_mask = (X['date'] >= covid_start) & (X['date'] <= covid_end)

    # Apply the multiplicative constant to bike counts in the COVID period
    X.loc[covid_mask, 'scaled_bike_count'] = X.loc[covid_mask, 'bike_count'] * covid_impact_factor

    # For dates outside the COVID period, the scaled count is the same as the original count
    X.loc[~covid_mask, 'scaled_bike_count'] = X.loc[~covid_mask, 'bike_count']

    return X

def covid_scaled_log_count(X):
    X = X.copy()
    # Apply ln(x+1) transformation to the scaled_bike_count
    X['scaled_log_bike_count'] = np.log1p(X['scaled_bike_count'])
    return X

def _distance_from_paris_centre(X):
    X = X.copy()  # modify a copy of X
    X.loc[:, 'distance_paris_centre'] = np.sqrt((X['latitude']-48.8565)**2 + (X['longitude']-2.3426)**2)
    
    return X


def column_to_drop(X):
    #return X.drop(['date','longitude','latitude','counter_technical_id','counter_id','site_id','counter_installation_date','coordinates', 'average_wind_direction' , 'average_wind_speed','horizontal_visibility','humidity','Temperature'],axis=1)
    #return X.drop(['date', 'counter_id', 'site_id', 'site_name', 'counter_name', 'counter_technical_id', 'latitude', 'longitude', 'counter_installation_date'], axis=1)
    return X.drop(['date', 'longitude', 'latitude'], axis=1)
#'counter_technical_id','counter_id','site_id','counter_installation_date','coordinates','counter_name','site_name'],axis=1)

# %%
def combined_transformer(X):
    X = _encode_dates(X)
    X = _distance_from_paris_centre(X)
    X = apply_confinement_status(X)
#     X = covid_scaled_count(X)
#     X = covid_scaled_log_count(X)
    X = column_to_drop(X)
    return X

# %%
df_train = pd.read_parquet("data/train.parquet")
final_df = combined_transformer(df_train)
final_df.head()
# Out:
#                 counter_id              counter_name    site_id  \
# 48321  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48324  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48327  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48330  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48333  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#                   site_name  bike_count counter_installation_date  \
# 48321  28 boulevard Diderot         0.0                2013-01-18
# 48324  28 boulevard Diderot         1.0                2013-01-18
# 48327  28 boulevard Diderot         0.0                2013-01-18
# 48330  28 boulevard Diderot         4.0                2013-01-18
# 48333  28 boulevard Diderot         9.0                2013-01-18
#
#       counter_technical_id  log_bike_count  year  month  day  weekday  hour  \
# 48321          Y2H15027244        0.000000  2020      9    1        1     2
# 48324          Y2H15027244        0.693147  2020      9    1        1     3
# 48327          Y2H15027244        0.000000  2020      9    1        1     4
# 48330          Y2H15027244        1.609438  2020      9    1        1    15
# 48333          Y2H15027244        2.302585  2020      9    1        1    18
#
#        distance_paris_centre  Confinement
# 48321               0.034459            0
# 48324               0.034459            0
# 48327               0.034459            0
# 48330               0.034459            0
# 48333               0.034459            0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor


def get_estimator():
    
    data_encoder = FunctionTransformer(combined_transformer)

        
    categorical_encoder = OneHotEncoder(handle_unknown="ignore")
    #categorical_cols = ["counter_name", "site_name"]

    preprocessor = ColumnTransformer(
        [
            #("date", date_encoder, ["date"])
            ("prepro", data_encoder, ["date", 'latitude', 'longitude']),
            #("dist", distance_encoder, ['latitude', 'longitude']),
            #("covid", covid_encoder, ['date']),
            #("cat", categorical_encoder, categorical_cols),
        ]
    )
#{'xgbregressor__subsample': 0.625, 'xgbregressor__reg_lambda': 1, 'xgbregressor__reg_alpha': 0.005, 'xgbregressor__n_estimators': 200, 'xgbregressor__max_depth': 7, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__gamma': 0.0, 'xgbregressor__colsample_bytree': 0.5}

    regressor = XGBRegressor(
        objective='reg:squarederror',
        subsample = 0.625,
        reg_lambda = 1,
        reg_alpha = 0.005,
        n_estimators = 200,
        max_depth = 7,
        learning_rate=0.1,
        gamma=0,
        colsample_bytree=0.25
    )
    # pipe = make_pipeline(preprocessor, regressor)
    pipe =  make_pipeline(preprocessor, regressor)

    
    return pipe



# Load data
df_train = pd.read_parquet("data/train.parquet")
df_test = pd.read_parquet("data/test.parquet")

df_train['site_name'] = df_train['site_name'].astype(str)
df_train['site_name'] = df_train['site_name'].replace(r'^Pont des Invalides (S-N|N-S)$', 'Pont des Invalides', regex=True)
df_train['site_name'] = df_train['site_name'].astype('category')

df_test['site_name'] = df_test['site_name'].astype(str)
df_test['site_name'] = df_test['site_name'].replace(r'^Pont des Invalides (S-N|N-S)$', 'Pont des Invalides', regex=True)
df_test['site_name'] = df_test['site_name'].astype('category')


df_train = covid_scaled_count(df_train)
df_train = covid_scaled_log_count(df_train)

# Extract features and target
X_train = df_train.drop(columns=['log_bike_count', 'bike_count', 'scaled_bike_count', 'scaled_log_bike_count'])
X_train.head()
y_train = df_train['scaled_log_bike_count']

# Train the model
pipeline = get_estimator()
pipeline.fit(X_train, y_train)

# Predict on test data
X_test = df_test.drop(columns=['log_bike_count','bike_count'])  
y_pred = pipeline.predict(X_test)

# %%
def RMSE_score(y_train, y_pred):
    RMSE = np.sum(np.sqrt((y_train - y_pred)**2)/len(y_pred))
    return RMSE

y_test = df_test['log_bike_count']
RMSE = RMSE_score(y_test, y_pred)
print(RMSE)
# Out:
# 0.582527750782344

# %%
# Placeholder feature names for the output of FunctionTransformer
# Assuming the output of FunctionTransformer equals the number of input features
placeholder_feature_names = ['feature_' + str(i) for i in range(X_train[['date', 'latitude', 'longitude']].shape[1])]

## Extracting feature names for one-hot encoded features
#categorical_feature_names = pipeline.named_steps['columntransformer'].named_transformers_['cat'].get_feature_names_out()


# Combine all feature names
#all_feature_names = placeholder_feature_names + list(categorical_feature_names)
all_feature_names = placeholder_feature_names 

# Get feature importances from the model
feature_importances = pipeline.named_steps['xgbregressor'].feature_importances_

# If the lengths don't match, truncate or pad the feature names list
if len(all_feature_names) < len(feature_importances):
    # Pad the feature names list with placeholders
    all_feature_names += ['extra_feature_' + str(i) for i in range(len(feature_importances) - len(all_feature_names))]
elif len(all_feature_names) > len(feature_importances):
    # Truncate the feature names list
    all_feature_names = all_feature_names[:len(feature_importances)]

# Create a DataFrame for easy plotting
features_df = pd.DataFrame({'Features': all_feature_names, 'Importance': feature_importances})

# Sort features by importance
features_df.sort_values(by='Importance', ascending=False, inplace=True)

# Plotting
plt.figure(figsize=(10,6))
features_df.plot(kind='bar', x='Features', y='Importance')
plt.title('Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()

print(features_df)
# Out:
#           Features  Importance
# 4  extra_feature_1    0.694188
# 5  extra_feature_2    0.170174
# 6  extra_feature_3    0.066872
# 1        feature_1    0.036648
# 3  extra_feature_0    0.029960
# 0        feature_0    0.001240
# 2        feature_2    0.000920

# %%
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

# %%
# Define the hyperparameter grid to search
param_grid = {
    'xgbregressor__max_depth': [3, 5, 7, 10],
    'xgbregressor__n_estimators': [50, 100, 200, 300],
    'xgbregressor__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'xgbregressor__subsample': np.linspace(0.5, 1, 5),
    'xgbregressor__colsample_bytree': np.linspace(0.5, 1, 5),
    'xgbregressor__gamma': np.linspace(0, 5, 5),
    'xgbregressor__reg_alpha': [0, 0.001, 0.005, 0.01, 0.05],
    'xgbregressor__reg_lambda': [0.01, 0.1, 1, 10, 100]
    
    # Add other parameters you want to tune
}

# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Define the pipeline (assuming it's already defined)
pipeline = get_estimator()

# RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='neg_mean_squared_error',
    cv=tscv,
    random_state=42,
    verbose=2
)

# Fit the RandomizedSearchCV to find the best parameters
random_search.fit(X_train, y_train)

# Best parameters
best_params = random_search.best_params_
print(f"Best parameters: {best_params}")

# Predict using the best model
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate (example: using mean squared error)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   3.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   3.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   4.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   5.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   3.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.75; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.75; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.75; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.75; total time=   3.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.75; total time=   4.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   3.0s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.875; total time=   0.7s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.875; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.875; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.875; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.875; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.5s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   3.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   3.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   3.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   3.5s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   4.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=1.0; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=1.0; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=1.0; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=1.0; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=3, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=1.0; total time=   2.5s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.5s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   3.4s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   3.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.6s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   3.2s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=3, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.75; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.5; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.5; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.5; total time=   3.7s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.5; total time=   4.6s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   3.5s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   3.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   3.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   0.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.875; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   3.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   3.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.75; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.875; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.75; total time=   0.8s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.75; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.75; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.75; total time=   2.3s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.75; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.5; total time=   2.3s
# ...
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.625; total time=   5.5s
# [CV] END xgbregressor__colsample_bytree=0.875, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.05, xgbregressor__reg_lambda=0.1, xgbregressor__subsample=0.625; total time=   6.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.0s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=5, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.001, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=1.0; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   1.4s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=1.0, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.5; total time=   3.3s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   1.1s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   2.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=7, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=100, xgbregressor__subsample=0.625; total time=   2.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   3.7s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.5; total time=   4.4s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   3.5s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=2.5, xgbregressor__learning_rate=0.01, xgbregressor__max_depth=5, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=1, xgbregressor__subsample=0.625; total time=   4.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   1.7s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   2.8s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=5, xgbregressor__n_estimators=200, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.875; total time=   3.1s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.625; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.625; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.625; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.625; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.2, xgbregressor__max_depth=10, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.005, xgbregressor__reg_lambda=0.01, xgbregressor__subsample=0.625; total time=   2.5s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.0s
# [CV] END xgbregressor__colsample_bytree=0.75, xgbregressor__gamma=5.0, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=3, xgbregressor__n_estimators=100, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.625; total time=   2.5s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.2s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   1.9s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   3.4s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=1.25, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=7, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=1.0; total time=   3.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   0.9s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   1.3s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   1.6s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   2.1s
# [CV] END xgbregressor__colsample_bytree=0.625, xgbregressor__gamma=3.75, xgbregressor__learning_rate=0.1, xgbregressor__max_depth=7, xgbregressor__n_estimators=50, xgbregressor__reg_alpha=0.01, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.75; total time=   2.4s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   1.8s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   2.7s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   3.6s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   4.5s
# [CV] END xgbregressor__colsample_bytree=0.5, xgbregressor__gamma=0.0, xgbregressor__learning_rate=0.05, xgbregressor__max_depth=10, xgbregressor__n_estimators=300, xgbregressor__reg_alpha=0, xgbregressor__reg_lambda=10, xgbregressor__subsample=0.5; total time=   5.1s
# Best parameters: {'xgbregressor__subsample': 0.625, 'xgbregressor__reg_lambda': 1, 'xgbregressor__reg_alpha': 0.005, 'xgbregressor__n_estimators': 200, 'xgbregressor__max_depth': 7, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__gamma': 0.0, 'xgbregressor__colsample_bytree': 0.5}
# Root Mean Squared Error: 0.4574289415026173

# %%
print(f"Best parameters: {best_params}")
# Out:
# Best parameters: {'xgbregressor__subsample': 0.625, 'xgbregressor__reg_lambda': 1, 'xgbregressor__reg_alpha': 0.005, 'xgbregressor__n_estimators': 200, 'xgbregressor__max_depth': 7, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__gamma': 0.0, 'xgbregressor__colsample_bytree': 0.5}
